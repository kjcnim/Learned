# %% [markdown]
# <a href="https://colab.research.google.com/github/kjcnim/Learned/blob/main/TF_LAB9-1_NN_for_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
#이번 LAB에서는 간단한 XOR만 보인다.
#다음 LAB에서 Neural Network를 보인다.
#XOR 진리표 입력
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units = 1, input_dim = 2, activation = 'sigmoid'))

#cost, gradient 계산!
tf.model.compile(loss = 'binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model.summary()

#epochs = 2000 일때 0.5이다.
history = tf.model.fit(x_data, y_data, epochs = 100)

predictions = tf.model.predict(x_data)
print('Prediction: \n', predictions)

score = tf.model.evaluate(x_data, y_data)
print('Accuracy: \n', score[1])

# 이렇게 했더니 잘 안된다. 정확도가 0.5밖에 안됨
# 그 이유는 neural net이 한 단 밖에 없기 때문이다.
# 따라서 방법이 하나의 단만 쓰는게 아니라 여러 단을 사용해서 문제를 풀어보자.
# LAB9-2에 있음.
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 1s 515ms/step - loss: 0.7540 - accuracy: 0.7500
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7537 - accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7534 - accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7531 - accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7528 - accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7525 - accuracy: 0.5000
# Epoch 7/100
# ...
