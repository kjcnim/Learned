# %% [markdown]
# <a href="https://colab.research.google.com/github/kjcnim/Learned/blob/main/TF_LAB10_2_NN%2C_ReLu%2C_Xavier%2C_Dropout%2C_and_Adam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 이번 LAB에서는 Neural Network를 적용하여 MNIST를 해결해본다.
# 초점은 NN을 사용했을 때, 이전보다 Accuracy가 더 높다는 것이다.

import numpy as np
import random
import tensorflow as tf

#for reproductibility
random.seed(777) 
learning_rate = 0.001
batch_size = 100
training_epochs = 15
nb_classes = 10

(x_train, y_train), (x_test2, y_test) = tf.keras.datasets.mnist.load_data()
print(x_train.shape)

#train과 test set으로 나눔
x_train = x_train.reshape(x_train.shape[0], 28 * 28)
x_test = x_test2.reshape(x_test2.shape[0], 28 * 28)

y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)

tf.model = tf.keras.Sequential()

#이 모델에서는 3 layers 사용
#첫번째 layer 설정
# activation function으로 relu를 사용한다.
# 그 이유는 이전에 사용하던 sigmoid는 layer가 많을 때, backpropagation에서 성능이 안좋았기 때문이다.
tf.model.add(tf.keras.layers.Dense(input_dim = 784, units = 256, activation = 'relu'))

#두번째 layer 설정
tf.model.add(tf.keras.layers.Dense(units = 256, activation = 'relu'))

#결과 출력 layer에서는 activation function으로 softmax 사용
tf.model.add(tf.keras.layers.Dense(units = nb_classes, activation = 'softmax'))

tf.model.compile(loss = 'categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(lr = learning_rate), metrics='accuracy')
tf.model.summary()

tf.model.fit(x_train, y_train, batch_size = batch_size, epochs = training_epochs)


# predict 10 random hand-writing data
y_predicted = tf.model.predict(x_test)

#random하게 mnist의 data를 읽어와서 실제값과 예측값이 같은지를 보는 for문이다.
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))

# evaluate test set
evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# (60000, 28, 28)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_13 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                2570
# ...
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 600/600 [==============================] - 4s 6ms/step - loss: 6.1412 - accuracy: 0.8438
# Epoch 2/15
# 600/600 [==============================] - 3s 6ms/step - loss: 0.4433 - accuracy: 0.9420
# Epoch 3/15
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2363 - accuracy: 0.9588
# Epoch 4/15
# ...
