# %% [markdown]
# <a href="https://colab.research.google.com/github/kjcnim/Learned/blob/main/TF_LAB9_2_NN_for_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# LAB 9-1에서 layer의 개수가 1개일 때 정확도가 0.5에 불과했다.
# 이번 LAB에서는 layer의 개수를 2개로 늘려보도록 하겠다.
# Layer 2개의 모식도는 실습9, ppt p11에 그려두었다.
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()

#첫번째 Layer 설정
# x_input이 2개이므로 input이 2개고, output도 2개로 설정
tf.model.add(tf.keras.layers.Dense(units = 2, input_dim = 2))
tf.model.add(tf.keras.layers.Activation('sigmoid'))

# 두번째 Layer 설정
# 위에서 ouput이 2개이므로 여기서 input은 2개이다.
# 결과를 출력해야하기에 output은 1개이다.
tf.model.add(tf.keras.layers.Dense(units = 1, input_dim = 2))
tf.model.add(tf.keras.layers.Activation('sigmoid'))

tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.1),  metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=100)

predictions = tf.model.predict(x_data)
print('Prediction: \n', predictions)

score = tf.model.evaluate(x_data, y_data)
print('Accuracy: ', score[1])

#이렇게 했더니 epochs= 10000일 때 정확도가 1로 정확한 결과값이 나옴을 확인할 수 있었다.
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_13 (Dense)             (None, 2)                 6
# _________________________________________________________________
# activation_2 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 3
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 0s 275ms/step - loss: 0.9099 - accuracy: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8942 - accuracy: 0.5000
# Epoch 3/100
# ...
